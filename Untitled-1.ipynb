# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
df= pd.read_csv('kc_house_data.csv')
df.head(10)
# Out:
#            id             date      price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000   221900.0         3       1.00         1180
# 1  6414100192  20141209T000000   538000.0         3       2.25         2570
# 2  5631500400  20150225T000000   180000.0         2       1.00          770
# 3  2487200875  20141209T000000   604000.0         4       3.00         1960
# 4  1954400510  20150218T000000   510000.0         3       2.00         1680
# 5  7237550310  20140512T000000  1230000.0         4       4.50         5420
# 6  1321400060  20140627T000000   257500.0         3       2.25         1715
# 7  2008000270  20150115T000000   291850.0         3       1.50         1060
# 8  2414600126  20150415T000000   229500.0         3       1.00         1780
# 9  3793500160  20150312T000000   323000.0         3       2.50         1890
#
#    floors  waterfront  view  condition  ...  yr_built  yr_renovated  zipcode  \
# 0     1.0           0     0          3  ...      1955             0    98178
# 1     2.0           0     0          3  ...      1951          1991    98125
# 2     1.0           0     0          3  ...      1933             0    98028
# 3     1.0           0     0          5  ...      1965             0    98136
# 4     1.0           0     0          3  ...      1987             0    98074
# 5     1.0           0     0          3  ...      2001             0    98053
# 6     2.0           0     0          3  ...      1995             0    98003
# 7     1.0           0     0          3  ...      1963             0    98198
# 8     1.0           0     0          3  ...      1960             0    98146
# 9     2.0           0     0          3  ...      2003             0    98038
#
#        lat     long  sqft_living15  sqft_lot15  sqft_lot  sqft_above  \
# 0  47.5112 -122.257           1340        5650      5650        1180
# 1  47.7210 -122.319           1690        7639      7242        2170
# 2  47.7379 -122.233           2720        8062     10000         770
# 3  47.5208 -122.393           1360        5000      5000        1050
# 4  47.6168 -122.045           1800        7503      8080        1680
# 5  47.6561 -122.005           4760      101930    101930        3890
# 6  47.3097 -122.327           2238        6819      6819        1715
# 7  47.4095 -122.315           1650        9711      9711        1060
# 8  47.5123 -122.337           1780        8113      7470        1050
# 9  47.3684 -122.031           2390        7570      6560        1890
#
#    sqft_basement
# 0              0
# 1            400
# 2              0
# 3            910
# 4              0
# 5           1530
# 6              0
# 7              0
# 8            730
# 9              0
#
# [10 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   floors         21613 non-null  float64
#  7   waterfront     21613 non-null  int64
#  8   view           21613 non-null  int64
#  9   condition      21613 non-null  int64
#  10  grade          21613 non-null  int64
#  11  yr_built       21613 non-null  int64
#  12  yr_renovated   21613 non-null  int64
#  13  zipcode        21613 non-null  int64
#  14  lat            21613 non-null  float64
#  15  long           21613 non-null  float64
#  16  sqft_living15  21613 non-null  int64
#  17  sqft_lot15     21613 non-null  int64
#  18  sqft_lot       21613 non-null  int64
#  19  sqft_above     21613 non-null  int64
#  20  sqft_basement  21613 non-null  int64
# dtypes: float64(5), int64(15), object(1)
# memory usage: 3.5+ MB

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.401822e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.673622e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#              floors    waterfront          view     condition         grade  \
# count  21613.000000  21613.000000  21613.000000  21613.000000  21613.000000
# mean       1.494309      0.007542      0.234303      3.409430      7.656873
# std        0.539989      0.086517      0.766318      0.650743      1.175459
# min        1.000000      0.000000      0.000000      1.000000      1.000000
# 25%        1.000000      0.000000      0.000000      3.000000      7.000000
# 50%        1.500000      0.000000      0.000000      3.000000      7.000000
# 75%        2.000000      0.000000      0.000000      4.000000      8.000000
# max        3.500000      1.000000      4.000000      5.000000     13.000000
#
#            yr_built  yr_renovated       zipcode           lat          long  \
# count  21613.000000  21613.000000  21613.000000  21613.000000  21613.000000
# mean    1971.005136     84.402258  98077.939805     47.560053   -122.213896
# std       29.373411    401.679240     53.505026      0.138564      0.140828
# min     1900.000000      0.000000  98001.000000     47.155900   -122.519000
# 25%     1951.000000      0.000000  98033.000000     47.471000   -122.328000
# 50%     1975.000000      0.000000  98065.000000     47.571800   -122.230000
# 75%     1997.000000      0.000000  98118.000000     47.678000   -122.125000
# max     2015.000000   2015.000000  98199.000000     47.777600   -121.315000
#
#        sqft_living15     sqft_lot15      sqft_lot    sqft_above  sqft_basement
# count   21613.000000   21613.000000  2.161300e+04  21613.000000   21613.000000
# mean     1986.552492   12768.455652  1.510697e+04   1788.390691     291.509045
# std       685.391304   27304.179631  4.142051e+04    828.090978     442.575043
# min       399.000000     651.000000  5.200000e+02    290.000000       0.000000
# 25%      1490.000000    5100.000000  5.040000e+03   1190.000000       0.000000
# 50%      1840.000000    7620.000000  7.618000e+03   1560.000000       0.000000
# 75%      2360.000000   10083.000000  1.068800e+04   2210.000000     560.000000
# max      6210.000000  871200.000000  1.651359e+06   9410.000000    4820.000000

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# sqft_lot         0
# sqft_above       0
# sqft_basement    0
# dtype: int64

# %%
df=df.drop(['id','zipcode'],axis=1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           21613 non-null  object
#  1   price          21613 non-null  float64
#  2   bedrooms       21613 non-null  int64
#  3   bathrooms      21613 non-null  float64
#  4   sqft_living    21613 non-null  int64
#  5   floors         21613 non-null  float64
#  6   waterfront     21613 non-null  int64
#  7   view           21613 non-null  int64
#  8   condition      21613 non-null  int64
#  9   grade          21613 non-null  int64
#  10  yr_built       21613 non-null  int64
#  11  yr_renovated   21613 non-null  int64
#  12  lat            21613 non-null  float64
#  13  long           21613 non-null  float64
#  14  sqft_living15  21613 non-null  int64
#  15  sqft_lot15     21613 non-null  int64
#  16  sqft_lot       21613 non-null  int64
#  17  sqft_above     21613 non-null  int64
#  18  sqft_basement  21613 non-null  int64
# dtypes: float64(5), int64(13), object(1)
# memory usage: 3.1+ MB

# %%
df['date'] = pd.to_datetime(df['date'])  

df['year'] = df['date'].dt.year
df['month'] = df['date'].dt.month
df.drop('date', axis=1, inplace=True)

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['price'])
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x=df['price'])
# Out:
# <Axes: xlabel='price'>

# %%
plt.figure(figsize=(10,6))
sns.countplot(x=df['bedrooms'],palette='Greens_d')
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_2028\2745548799.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['bedrooms'],palette='Greens_d')
# <Axes: xlabel='bedrooms', ylabel='count'>

# %%
sns.countplot(x=df['floors'],palette='Set2')
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_2028\2342491962.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['floors'],palette='Set2')
# <Axes: xlabel='floors', ylabel='count'>

# %%
plt.figure(figsize=(15,6))
sns.countplot(x=df['bathrooms'],palette='Set2')
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_2028\2524937488.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['bathrooms'],palette='Set2')
# <Axes: xlabel='bathrooms', ylabel='count'>

# %%
sns.countplot(x=df['grade'],palette='Set2')
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_2028\824831147.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['grade'],palette='Set2')
# <Axes: xlabel='grade', ylabel='count'>

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x=df['sqft_living'],y=df['price'])
# Out:
# <Axes: xlabel='sqft_living', ylabel='price'>

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x=df['sqft_lot'],y=df['price'])
# Out:
# <Axes: xlabel='sqft_lot', ylabel='price'>

# %%
sns.scatterplot(x=df['sqft_above'],y=df['price'])
# Out:
# <Axes: xlabel='sqft_above', ylabel='price'>

# %%
sns.scatterplot(x=df['sqft_basement'],y=df['price'])
# Out:
# <Axes: xlabel='sqft_basement', ylabel='price'>

# %%
df.corr()['price'].sort_values(ascending=False)
# Out:
# price            1.000000
# sqft_living      0.702044
# grade            0.667463
# sqft_above       0.605566
# sqft_living15    0.585374
# bathrooms        0.525134
# view             0.397346
# sqft_basement    0.323837
# bedrooms         0.308338
# lat              0.306919
# waterfront       0.266331
# floors           0.256786
# yr_renovated     0.126442
# sqft_lot         0.089655
# sqft_lot15       0.082456
# yr_built         0.053982
# condition        0.036392
# long             0.021571
# year             0.003554
# month           -0.010053
# Name: price, dtype: float64

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
fig=plt.figure(figsize=(15,6))
fig.add_subplot(1,2,1)
df.groupby('year')['price'].mean().plot()
fig.add_subplot(1,2,2)
df.groupby('month')['price'].mean().plot()
# Out:
# <Axes: xlabel='month'>

# %% [markdown]
# ## using 1 feature

# %%
x=df['sqft_living']
y=df['price']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
regressor=LinearRegression()
regressor.fit(x_train.values.reshape(-1,1),y=y_train)
print('Intercept:',regressor.intercept_)
print('Slope:',regressor.coef_)
# Out:
# Intercept: -42291.12839802564
# Slope: [279.73977846]

# %%
y_pred=regressor.predict(x_test.values.reshape(-1,1))
data=pd.DataFrame({'Actual':y_test,'Predicted':y_pred})
data.head(10)
# Out:
#           Actual     Predicted
# 735     365000.0  5.367702e+05
# 2830    865000.0  7.689542e+05
# 4106   1040000.0  1.012328e+06
# 16218  1490000.0  1.233322e+06
# 19964   711000.0  6.710453e+05
# 1227    211000.0  4.360639e+05
# 18849   790000.0  7.102089e+05
# 19369   680000.0  4.612405e+05
# 20164   384500.0  4.052925e+05
# 7139    605000.0  2.122721e+05

# %%
print('Mean Absolute Error: {:.2f}'.format(metrics.mean_absolute_error(y_test, y_pred))) 
print('Mean Squared Error:{:.2f}'.format(metrics.mean_squared_error(y_test, y_pred)))  
print('Root Mean Squared Error:{:.2f}'.format(np.sqrt(metrics.mean_squared_error(y_test, y_pred))))
# Out:
# Mean Absolute Error: 177990.77
# Mean Squared Error:76570251342.04
# Root Mean Squared Error:276713.30

# %% [markdown]
# ## multiple linear regression

# %%
X=df.drop('price',axis=1)
Y=df['price']
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3,random_state=101)

# %%
Regressor=LinearRegression()
Regressor.fit(X_train,Y_train)
print('Intercept:',Regressor.intercept_)
print('Slope:',Regressor.coef_)
# Out:
# Intercept: -112141298.74585912
# Slope: [-3.57318804e+04  3.66539461e+04  1.09170515e+02  6.25636469e+03
#   5.54651830e+05  4.81188859e+04  3.43112692e+04  9.82788380e+04
#  -2.45024409e+03  2.24839280e+01  5.62958014e+05 -1.20815289e+05
#   2.84999200e+01 -3.65273039e-01  1.40968317e-01  7.12652052e+01
#   3.79053100e+01  3.70793354e+04  1.31399254e+03]

# %%
Y_pred=Regressor.predict(X_test)
data1=pd.DataFrame({'Actual':Y_test,'Predicted':Y_pred})
data1.head(10)
# Out:
#          Actual      Predicted
# 3834   349950.0  530524.834376
# 1348   450000.0  665649.182546
# 20366  635000.0  552368.638510
# 16617  355500.0  346947.210019
# 20925  246950.0   62479.133802
# 7891   406550.0  481512.654028
# 939    350000.0  313918.092742
# 10502  226500.0  273708.041647
# 2948   265000.0  279965.581799
# 5079   656000.0  534602.271487

# %%
print('Mean Squared Error:{:.2f}'.format(metrics.mean_squared_error(Y_test, Y_pred)))
# Out:
# Mean Squared Error:41459260836.68
